# %%
from itertools import combinations
from z3 import *
import numpy as np
from total_sat import at_least_one, at_most_one, exactly_one
import time

# %% [markdown]
# ## Instance Collection

# %%
instance_collection = {}

# %% [markdown]
# ### Instance 1

# %%
## Instance 1
m = 2
n = 6
l = [ 15,10 ]
s = [ 3,2,6,5,4,4 ]
D = [[0,3,4,5,6,6,2],
     [3,0,1,4,5,7,3],
     [4,1,0,5,6,6,4],
     [4,4,5,0,3,3,2],
     [6,7,8,3,0,2,4],
     [6,7,8,3,2,0,4],
     [2,3,4,3,4,4,0]]

instance = {
    'm' : m,
    'n' : n,
    'l' : l,
    's' : s,
    'D' : D
}

instance_collection['instance_1'] = instance

# %% [markdown]
# ### Instance 2

# %%
## Instance 2
m = 6
n = 9
l = [ 190,185,185,190,195,185 ]
s = [ 11,11,23,16,2,1,24,14,20 ]
D = [[0,199,119,28,179,77,145,61,123,87],
     [199,0,81,206,38,122,55,138,76,113],
     [119,81,0,126,69,121,26,117,91,32],
     [28,206,126,0,186,84,152,68,130,94],
     [169,38,79,176,0,92,58,108,46,98],
     [77,122,121,84,102,0,100,16,46,96],
     [145,55,26,152,58,100,0,91,70,58],
     [61,138,113,68,118,16,91,0,62,87],
     [123,76,91,130,56,46,70,62,0,66],
     [87,113,32,94,94,96,58,87,66,0]
     ]

instance = {
    'm' : m,
    'n' : n,
    'l' : l,
    's' : s,
    'D' : D
}

instance_collection['instance_2'] = instance

# %% [markdown]
# ### Instance 3

# %%
## Instance 3
m = 3
n = 7
l = [ 15,10,7 ]
s = [ 3,2,6,8,5,4,4 ]
D = [[0,3,3,6,5,6,6,2],
     [3,0,6,3,4,7,7,3],
     [3,4,0,7,6,3,5,3],
     [6,3,7,0,5,6,7,4],
     [5,4,6,3,0,3,3,3],
     [6,7,3,6,3,0,2,4],
     [6,7,5,6,3,2,0,4],
     [2,3,3,4,3,4,4,0]
     ]

instance = {
    'm' : m,
    'n' : n,
    'l' : l,
    's' : s,
    'D' : D
}

instance_collection['instance_3'] = instance

# %% [markdown]
# ### Instance 4

# %%
m = 8
n = 10
l = [ 200,180,160,185,180,200,160,200 ]
s = [ 10,25,18,16,14,16,24,19,23,19 ]
D = [[0,56,86,77,81,128,107,154,70,93,53],
     [56,0,79,31,62,87,61,107,37,37,24],
     [86,79,0,109,17,43,110,68,43,69,55],
     [87,31,109,0,92,116,30,77,66,40,55],
     [81,62,17,92,0,47,93,82,26,52,38],
     [128,87,43,116,47,0,117,52,58,76,75],
     [116,61,110,30,93,117,0,65,67,41,63],
     [163,107,78,77,82,52,65,0,93,70,110],
     [70,41,43,66,26,73,67,93,0,26,17],
     [93,37,69,40,52,76,41,70,26,0,40],
     [53,24,55,54,38,75,63,110,17,40,0]
     ]

instance = {
    'm' : m,
    'n' : n,
    'l' : l,
    's' : s,
    'D' : D
}

instance_collection['instance_4'] = instance

# %% [markdown]
# ### Instance 5

# %%
m = 2
n = 3
l = [ 18,30 ]
s = [ 20,17,6 ]
D = [[0,21,86,99],
     [21,0,71,80],
     [92,71,0,61],
     [59,80,61,0]
     ]

instance = {
    'm' : m,
    'n' : n,
    'l' : l,
    's' : s,
    'D' : D
}

instance_collection['instance_5'] = instance

# %% [markdown]
# ### Instance 6

# %%
m = 6
n = 8
l = [ 200,100,200,300,200,100 ]
s = [ 16,25,21,14,19,14,6,20 ]
D = [[0,80,131,22,41,127,87,48,113],
     [60,0,85,82,101,81,53,106,57],
     [141,83,0,129,182,4,64,189,28],
     [22,82,129,0,55,125,65,66,101],
     [41,99,172,55,0,168,118,11,154],
     [137,81,4,125,178,0,60,185,32],
     [77,63,64,65,118,60,0,125,36],
     [48,126,179,60,58,175,125,0,161],
     [113,57,28,101,154,24,36,161,0]
     ]

instance = {
    'm' : m,
    'n' : n,
    'l' : l,
    's' : s,
    'D' : D
}

instance_collection['instance_6'] = instance

# %% [markdown]
# ### Instance 7

# %%
m = 6
n = 17
l = [ 190,185,185,190,195,185 ]
s = [ 11,11,23,16,2,1,24,14,20,10,11,22,2,12,9,21,10 ]
D = [[0,20,19,28,58,48,45,32,90,61,71,59,65,46,72,51,46,66],
     [103,0,81,107,38,110,55,94,76,123,88,76,69,86,99,113,108,106],
     [73,41,0,80,40,29,26,13,75,42,70,58,46,27,53,32,27,47],
     [28,48,47,0,55,59,52,60,62,58,43,31,40,21,59,48,53,61],
     [83,38,79,87,0,102,58,92,56,103,68,56,49,67,79,94,106,86],
     [76,44,72,83,43,0,98,16,46,64,73,61,73,67,27,40,30,43],
     [65,55,26,64,58,55,0,39,69,68,50,38,26,31,66,58,53,56],
     [60,28,56,67,27,16,82,0,62,48,75,63,69,51,40,24,14,34],
     [58,76,77,81,55,46,69,62,0,56,43,31,43,53,23,80,76,30],
     [74,79,42,84,71,35,68,51,56,0,59,47,54,37,59,24,65,43],
     [15,35,34,43,12,43,41,47,39,47,0,12,24,10,16,37,61,32],
     [27,47,46,50,24,55,38,59,31,47,12,0,12,22,28,49,73,30],
     [39,59,46,38,36,56,26,59,43,54,24,12,0,19,40,45,73,37],
     [58,68,27,57,55,38,31,40,62,37,43,31,19,0,59,27,54,50],
     [61,68,80,84,58,27,72,40,23,59,46,34,46,56,0,64,54,16],
     [76,55,32,83,54,11,58,27,57,24,61,49,45,27,38,0,41,54],
     [46,14,42,53,13,21,68,14,67,34,71,59,55,37,48,10,0,47],
     [57,61,76,75,54,43,56,34,30,43,42,30,37,50,16,57,47,0]
     ]

instance = {
    'm' : m,
    'n' : n,
    'l' : l,
    's' : s,
    'D' : D
}

instance_collection['instance_7'] = instance

# %% [markdown]
# ### Instance 8

# %%
m = 8
n = 10
l = [ 180,160,185,200,180,160,175,200 ]
s = [ 10,25,18,16,14,7,9,16,24,19 ]
D = [[0,56,86,87,81,128,107,163,166,98,93],
     [56,0,80,31,63,87,61,107,119,76,37],
     [86,71,0,102,17,42,111,77,90,12,70],
     [87,31,110,0,93,116,30,77,89,105,40],
     [81,63,17,93,0,47,94,82,94,17,53],
     [128,87,42,116,47,0,117,52,92,30,76],
     [117,61,111,30,94,117,0,65,59,106,41],
     [163,107,77,77,82,52,65,0,40,65,70],
     [166,110,90,79,94,92,49,40,0,82,82],
     [98,76,12,105,17,30,106,65,82,0,65],
     [93,37,70,40,53,76,41,70,82,65,0]
     ]

instance = {
    'm' : m,
    'n' : n,
    'l' : l,
    's' : s,
    'D' : D
}

instance_collection['instance_8'] = instance

# %% [markdown]
# ### Instance 9

# %%
m = 10
n = 13
l = [ 180,190,210,200,195,180,210,200,195,210 ]
s = [ 4,12,3,15,13,20,21,4,25,21,7,3,9 ]
D = [[0,49,80,59,112,79,112,187,28,47,36,69,138,54],
     [49,0,43,107,93,30,92,236,74,9,79,38,187,15],
     [80,43,0,132,136,73,135,261,104,52,109,11,212,28],
     [69,107,138,0,171,137,171,129,87,105,33,127,80,112],
     [112,93,136,171,0,79,13,186,84,84,148,131,149,108],
     [79,30,73,137,79,0,66,265,103,32,108,68,216,45],
     [112,92,135,171,13,66,0,199,84,83,148,130,150,107],
     [187,211,168,129,186,241,199,0,162,220,158,179,49,196],
     [28,74,104,87,84,103,84,162,0,71,64,93,113,78],
     [47,9,52,105,84,32,83,233,71,0,76,47,184,24],
     [36,79,109,33,148,108,148,158,64,76,0,98,109,83],
     [69,38,11,121,131,68,130,250,93,47,98,0,201,23],
     [138,162,119,80,149,192,150,49,113,171,109,130,0,147],
     [54,15,28,112,108,45,107,240,78,24,83,23,191,0]
     ]


instance = {
    'm' : m,
    'n' : n,
    'l' : l,
    's' : s,
    'D' : D
}

instance_collection['instance_9'] = instance

# %% [markdown]
# ### Instance 10

# %%
m = 10
n = 13
l = [ 185,190,200,180,200,190,200,180,195,190 ]
s = [ 22,17,10,8,14,12,17,19,25,25,6,21,6 ]
D = [[0,21,86,14,84,72,24,54,83,70,8,91,42,57],
     [21,0,71,35,70,51,16,75,62,91,29,70,57,52],
     [86,71,0,100,39,70,87,137,81,73,78,103,128,33],
     [14,35,100,0,98,86,38,49,97,56,22,105,29,71],
     [84,70,39,98,0,109,86,135,120,57,76,129,126,27],
     [63,51,70,77,109,0,49,117,11,133,71,64,90,103],
     [24,16,87,38,86,49,0,78,60,94,32,67,41,60],
     [63,84,137,49,135,135,87,0,146,79,59,154,65,108],
     [74,62,81,88,120,11,60,128,0,144,82,68,94,114],
     [70,91,73,56,57,142,94,79,153,0,63,161,72,40],
     [8,29,78,22,76,80,32,59,91,63,0,99,50,49],
     [91,70,133,105,129,64,67,145,68,161,99,0,91,122],
     [42,57,128,29,126,90,41,65,94,72,50,91,0,99],
     [57,52,33,71,27,103,60,108,114,40,49,122,99,0]
     ]

instance = {
    'm' : m,
    'n' : n,
    'l' : l,
    's' : s,
    'D' : D
}

instance_collection['instance_9'] = instance

# %%
PACKS = range(n)
COURIERS = range(m)
DEPOT = (n)
LOCATIONS = range(DEPOT+1)

# %% [markdown]
# ## Assignments and Paths model

# %%
class Assignments():
    def __init__(self, instance):
        self.solver, self.assignment = solve_assignment_sat(
            loads = instance['l'],
            sizes = instance['s']
        )

    def solve(self):
        # Solve the problem
        # solver_assignments.set("timeout", 10)
        if self.solver.check() == sat:
            model = self.solver.model()

            # Provare a inserire le statistiche come output della solve
            # print ("statistics for the last check method...")
            # print (s.statistics())
            # # Traversing statistics
            # for k, v in s.statistics():
            #     print ("%s : %s" % (k, v))

            # Constraint to ensure new assignments are different than ones already tried
            self.solver.add(Not(And([model.evaluate(self.assignment[p][c]) == self.assignment[p][c] for c in COURIERS for p in PACKS])))
            
            return [[model.evaluate(self.assignment[p][c]) for c in COURIERS] for p in PACKS]
        
        # Provare a inserire le statistiche come output della solve
        # print ("statistics for the last check method...")
        # print (s.statistics())
        # # Traversing statistics
        # for k, v in s.statistics():
        #     print ("%s : %s" % (k, v))
        return None

def solve_assignment_sat(loads, sizes):
    # Decision variables
    assignments = [[Bool(f"a_{p}_{c}") for c in COURIERS] for p in PACKS]


    solver_assignments = Solver()

    ## Capacity constraint - assure that sum of weights of a singular courier is under its load limit
    for c in COURIERS:
        sum_load = Sum([If(assignments[p][c], sizes[p], 0) for p in PACKS])
        solver_assignments.add(sum_load <= loads[c])
    
    ## Capacity constraint - ensure that each pack is delivered only by a courier
    for p in PACKS:
        solver_assignments.add(exactly_one([assignments[p][c] for c in COURIERS]))
    
    return solver_assignments, assignments

# %%
class Paths():
    def __init__(self, instance):
        self.solver, self.assignments, self.paths = solve_path_sat(
            n = instance['n'],
            loads = instance['l']
        )
        self.distances = instance['D']

    def solve(self, assignments_result):
        # Solve the problem
        # solver_assignments.set("timeout", 10)
        ## Set assignments obtained through precedent model
        self.solver.push()
        for p in PACKS:
            for c in COURIERS:
                self.solver.add(assignments_result[p][c] == self.assignments[p][c])

        # Init
        objective = None
        solution_ls = []


        while self.solver.check() == sat:
            model = self.solver.model()

            # obtain Objective value
            # objective = max([
            #     sum([self.distances[loc1][loc2] if model.evaluate(self.paths[c][loc1][loc2]) else 0
            #         for loc1 in LOCATIONS for loc2 in LOCATIONS if loc1!=loc2])
            #     for c in COURIERS
            #     ])
        
            # Compose solution
            solution = []
            paths_distance = []
            for c in COURIERS:
                courier_path = []

                loc1 = DEPOT
                distance = 0
                while True:
                    step = sum([loc2+1 if model.evaluate(self.paths[c][loc1][loc2]) else 0 for loc2 in LOCATIONS if loc1!=loc2])

                    distance += self.distances[loc1][step-1]
                    if (step-1) == DEPOT:
                        break
                    else:
                        loc1 = step-1

                    if step != 0:
                        courier_path.append(step)
                solution.append(courier_path)
                paths_distance.append(distance)
            solution_ls.append(solution)

            objective = max(paths_distance)
        
            # solution = [[sum([loc2+1 for loc2 in LOCATIONS if (model.evaluate(paths[c][loc1][loc2]) and loc1!=loc2)]) for loc1 in LOCATIONS] for c in COURIERS]

            print(f'Objective: {objective}')
            print(f'Solution: {solution}')

            for c in COURIERS:
                total_distance = Sum([If(self.paths[c][loc1][loc2], self.distances[loc1][loc2], 0) for loc1 in LOCATIONS for loc2 in LOCATIONS if loc1!=loc2])
                self.solver.add(total_distance < objective)

            # Provare a inserire le statistiche come output della solve
            # print ("statistics for the last check method...")
            # print (s.statistics())
            # # Traversing statistics
            # for k, v in s.statistics():
            #     print ("%s : %s" % (k, v))
        
        self.solver.pop()
        if (objective is not None):
            ## Adding specific constraint to ensure total distance is less than the objective value for the nex time the solver is running
            for c in COURIERS:
                total_distance = Sum([If(self.paths[c][loc1][loc2], self.distances[loc1][loc2], 0) for loc1 in LOCATIONS for loc2 in LOCATIONS if loc1!=loc2])
                self.solver.add(total_distance < objective)

            return objective, solution_ls[-1]
        return objective, solution_ls

def solve_path_sat(n, loads):
    # Decision variables
    assignments = [[Bool(f"a_{p}_{c}") for c in COURIERS] for p in PACKS]
    paths = [[[Bool(f'p_{c}_{loc1}_{loc2}') for loc2 in LOCATIONS] for loc1 in LOCATIONS] for c in COURIERS]

    # Auxiliar variables
    carry_num = [[Bool(f'c_{c}_{p1}') for p1 in PACKS] for c in COURIERS] # Counter of how many packages a courier is delivering

    solver_paths = Solver()

    # Soft Constraint for symmetry breaking
    for c1 in COURIERS:
        for c2 in COURIERS:
            if (c1 < c2 and loads[c1]==loads[c2]):
                for p1 in PACKS:
                    for p2 in PACKS:
                        solver_paths.add(Implies(And(carry_num[c1][p1], carry_num[c2][p2]), p1 <= p2))
                # solver_paths.add(carry_num[c1] <= carry_num[c2])
    
    ## Path related constraints
    # 1 - Nel path deve esistere uno step con valore del pacco True con indice = DEPOT (n+1)
    for c in COURIERS:
        # If courier has at_least_one package to deliver, its path[c][DEPOT] must have a destination != DEPOT
        solver_paths.add(Implies(at_least_one([assignments[p][c] for p in PACKS]), paths[c][DEPOT][DEPOT]==False))

        # If courier has no package to deliver, it can stay in DEPOT
        solver_paths.add(Implies(Not(at_least_one([assignments[p][c] for p in PACKS])), paths[c][DEPOT][DEPOT]==True))

        for p in PACKS:
            solver_paths.add(Implies(assignments[p][c], paths[c][p][p]==False))
            solver_paths.add(Implies(Not(assignments[p][c]), paths[c][p][p]==True))

    # 2 - ensuring pack is delivered by a single courier only once
    for c in COURIERS:
        for loc in LOCATIONS:
            solver_paths.add(exactly_one([paths[c][loc][ind] for ind in LOCATIONS]))

    ## Subcircuit constraint
    # 1 - alldifferent per ogni path di ogni courier
    for c in COURIERS:
        for loc in LOCATIONS:
            solver_paths.add(exactly_one([paths[c][ind][loc] for ind in LOCATIONS]))

    # 2 - subtour elimination
    # Variables: u[i] to prevent subtours
    u = [[[Bool(f"u_{i}_{j}_{k}") for k in PACKS] for j in PACKS] for i in COURIERS]

    # Constraining assignment of truth value of u decision variable
    for c in COURIERS:
        # u del primo pacco = 1
        for p in PACKS:
            solver_paths.add(Implies(paths[c][DEPOT][p], u[c][p][0]==True))

        # u_j >= u_i + 1
        for p1 in PACKS:
            for p2 in PACKS:
                if p1 == p2:
                    continue

                for k in PACKS:
                    solver_paths.add(Implies(And(paths[c][p1][p2], u[c][p1][k]), And(exactly_one([u[c][p2][i] for i in range(k+1, n)]))))

    ## Exatcly one true value for each u_p1
    for c in COURIERS:
        for p1 in PACKS:
            solver_paths.add(exactly_one(u[c][p1]))

    # Applying MTZ formulation constraint
    # u_i - u_j + 1 <= (n - 1) * (1 - paths[c, i, j])
    for c in COURIERS:
        for p1 in PACKS: # i
            for p2 in PACKS: #j
                if p1 == p2:
                    continue

                for k1 in PACKS:
                    for k2 in PACKS:
                        solver_paths.add(Implies(And(u[c][p1][k1], u[c][p2][k2]), k1 - k2 + 1 <= (n-1) * (1-If(paths[c][p1][p2], 1, 0))))

    return solver_paths, assignments, paths

# %% [markdown]
# ## Assignment and Path model declaration

# %%
# Declaration of the 2 problems class
assignments_problem = Assignments(instance)
paths_problem = Paths(instance)

set_option("sat.random_seed", 42)
set_option("sat.local_search", True)
# set_option("sat.restart", 'luby') # ema, luby, static or geometric
# set_option("sat.ddfw_search", True)
# Setting up pretty solution dictionary
solution_dict = {
    'objective':100000,
    'solution':None,
    'is_optimal': False,
    'time':None,
    'timeout':False,
}

# Initializing time measure
init_time = time.time()

# Setting Timeout False
timeout = False

# Try Counter
i = 0
while (timeout==False):

    # Obtain a first assignment to variable assignment (=> which courier deliver each pack)
    print(f'({i+1}) - try assignment')
    assignment_result = assignments_problem.solve()

    # If this first problem is unsat => it doesn't find a solution: break
    if assignment_result == None:
        print(f'({i+1}) - assignment break')
        end_time = time.time()
        diff_time = end_time-init_time
        solution_dict['time'] = diff_time
        if solution_dict['objective'] == 100000:
            solution_dict['objective'] = None
        else:
            solution_dict['is_optimal'] = True
        break

    # Obtain actual final result (Objective)
    print(f'({i+1}) - try paths')
    objective, solution = paths_problem.solve(
            assignments_result = assignment_result
        )

    # Initializing pretty solution storage
    if objective is not None:
        if (objective < solution_dict['objective']):
            solution_dict['objective'] = objective
            solution_dict['solution'] = solution

    # Time statistics measure
    end_time = time.time()
    diff_time = end_time-init_time

    # Checking timeout
    if diff_time>=300:
        solution_dict['time'] = diff_time
        timeout=True
        solution_dict['timeout'] = timeout
        
    # Chacking optimality
    # if unsat_status:
    #     solution_dict['time'] = diff_time
    #     solution_dict['is_optimal'] = True
    #     break
    i += 1

# i = 0
# while True:

#     # Obtain a first assignment to variable assignment (=> which courier deliver each pack)
#     print(f'({i+1}) - try assignment')
#     assignment_result = assignments_problem.solve()

#     # If this first problem is unsat => it doesn't find a solution: break
#     if assignment_result == None:
#         print(f'({i+1}) - assignment break')
#         break

#     # Obtain actual final result (Objective)
#     print(f'({i+1}) - try paths')
#     objective, solution = paths_problem.solve(
#             assignments_result = assignment_result
#         )

#     # if new final result worse than before: break
#     # if objective >= last_objective:
#     #     print(f'({i+1}) - paths break')

#     #     break

#     i += 1
# Out:
# (1) - try assignment
# (1) - try paths
# Objective: 18
# Solution: [[7, 4, 1], [6, 3], [5, 2]]
# (2) - try assignment
# (2) - try paths
# (3) - try assignment
# (3) - try paths
# Objective: 14
# Solution: [[2, 4, 5], [3, 6], [7, 1]]
# Objective: 12
# Solution: [[5, 4, 2], [3, 6], [7, 1]]
# (4) - try assignment
# (4) - try paths
# (5) - try assignment
# (5) - try paths
# (6) - try assignment
# (6) - try paths
# (7) - try assignment
# (7) - assignment break

# %%
solution_dict
# Out:
# {'objective': 12,
#  'solution': [[5, 4, 2], [3, 6], [7, 1]],
#  'is_optimal': True,
#  'time': 0.13657140731811523,
#  'timeout': False}

# %% [markdown]
# - provare modello unico sia per assignment che per path - quite good
# - symmetry breaking: ordinamento dei pacchi (lex) per i corrieri con stessa capacità - devo vedere come fare lex
# - return last solution, e statistiche per il main => {tempo, solution, objective, ...} - optimal come controllare? timeout controllato da fuori?
# - lower_bound => stima della lunghezza del percorso minimo => se objective < stima,

# %% [markdown]
# ## Unified Model definition

# %%
def Max(vs):
  m = vs[0]
  for v in vs[1:]:
    m = If(v > m, v, m)
  return m

class Unified_Model():
    def __init__(self, instance):
        self.solver, self.assignment, self.paths = create_model(
            m = instance['m'],
            n = instance['n'],
            loads = instance['l'],
            sizes = instance['s'],
            distances = instance['D']
        )
        self.instance = instance
        self.distances = instance['D']

    def solve(self):

        ## Useful ranges
        PACKS = range(self.instance['n'])
        COURIERS = range(self.instance['m'])
        DEPOT = (self.instance['n'])
        LOCATIONS = range(DEPOT+1)

        # Solve the problem
        # solver_assignments.set("timeout", 10)
        ## Set assignments obtained through precedent model
        self.solver.push()

        ##### Estimated distance for the minimum path
        lower_bound = max([self.distances[DEPOT][p] + self.distances[p][DEPOT] for p in PACKS])

        Objective = Max([
                Sum([If(self.paths[c][loc1][loc2], self.distances[loc1][loc2], 0)
                    for loc1 in LOCATIONS for loc2 in LOCATIONS if loc1!=loc2])
                for c in COURIERS
                ])

        # Constraint - ensuring distance percurred by each courier to be greater than estimated lower bound
        self.solver.add(Objective >= lower_bound)
        # for c in COURIERS:
        #     total_distance = Sum([If(self.paths[c][loc1][loc2], self.distances[loc1][loc2], 0) for loc1 in LOCATIONS for loc2 in LOCATIONS if loc1!=loc2])
        #     self.solver.add(total_distance >= lower_bound)

        # Init
        objective = None
        solution_ls = []

        ## Check if problem has become unsat
        unsat_status = True

        # self.solver.set("timeout", 120)

        while self.solver.check() == sat:

            # problem is still satisfiable
            unsat_status = False

            model = self.solver.model()

            # obtain Objective value
            objective = max([
                sum([self.distances[loc1][loc2] if model.evaluate(self.paths[c][loc1][loc2]) else 0
                    for loc1 in LOCATIONS for loc2 in LOCATIONS if loc1!=loc2])
                for c in COURIERS
                ])
        
            # Compose solution
            solution = []
            # paths_distance = []
            for c in COURIERS:
                courier_path = []

                loc1 = DEPOT
                # distance = 0
                while True:
                    step = sum([loc2+1 if model.evaluate(self.paths[c][loc1][loc2]) else 0 for loc2 in LOCATIONS if loc1!=loc2])

                    # distance += self.distances[loc1][step-1]
                    if (step-1) == DEPOT:
                        break
                    else:
                        loc1 = step-1

                    if step != 0:
                        courier_path.append(step)
                solution.append(courier_path)
                # paths_distance.append(distance)
            solution_ls.append(solution)

            # objective = max(paths_distance)
        
            # solution = [[sum([loc2+1 for loc2 in LOCATIONS if (model.evaluate(paths[c][loc1][loc2]) and loc1!=loc2)]) for loc1 in LOCATIONS] for c in COURIERS]

            print(f'Objective: {objective}')
            print(f'Solution: {solution}')

            for c in COURIERS:
                total_distance = Sum([If(self.paths[c][loc1][loc2], self.distances[loc1][loc2], 0) for loc1 in LOCATIONS for loc2 in LOCATIONS if loc1!=loc2])
                self.solver.add(total_distance < objective)
            
            # Constraint to ensure new assignments are different than ones already tried
            self.solver.add(Not(And([model.evaluate(self.assignment[p][c]) == self.assignment[p][c] for c in COURIERS for p in PACKS])))

            # Provare a inserire le statistiche come output della solve
            # print ("statistics for the last check method...")
            # print (s.statistics())
            # # Traversing statistics
            # for k, v in s.statistics():
            #     print ("%s : %s" % (k, v))
        
        self.solver.pop()
        if (objective is not None):
            ## Adding specific constraint to ensure total distance is less than the objective value for the nex time the solver is running
            for c in COURIERS:
                total_distance = Sum([If(self.paths[c][loc1][loc2], self.distances[loc1][loc2], 0) for loc1 in LOCATIONS for loc2 in LOCATIONS if loc1!=loc2])
                self.solver.add(total_distance < objective)

            return objective, solution_ls[-1], unsat_status
        return objective, solution_ls, unsat_status

def create_model(m, n, loads, sizes, distances):
    ## Useful ranges
    PACKS = range(n)
    COURIERS = range(m)
    DEPOT = (n)
    LOCATIONS = range(DEPOT+1)

    ###### Previous assignment model
    # Decision variables
    assignments = [[Bool(f"a_{p}_{c}") for c in COURIERS] for p in PACKS]


    solver_unified = Solver()

    # Capacity constraint - assure that sum of weights of a singular courier is under its load limit
    for c in COURIERS:
        sum_load = Sum([If(assignments[p][c], sizes[p], 0) for p in PACKS])
        solver_unified.add(sum_load <= loads[c])
    
    # Capacity constraint - ensure that each pack is delivered only by a courier
    for p in PACKS:
        solver_unified.add(exactly_one([assignments[p][c] for c in COURIERS]))
    

    

    ###### Previous paths model
    # Decision variables
    # assignments = [[Bool(f"a_{p}_{c}") for c in COURIERS] for p in PACKS]
    paths = [[[Bool(f'p_{c}_{loc1}_{loc2}') for loc2 in LOCATIONS] for loc1 in LOCATIONS] for c in COURIERS]

    # Auxiliar variables
    # carry_num = [[Bool(f'c_{c}_{p1}') for p1 in PACKS] for c in COURIERS] # Counter of how many packages a courier is delivering

    # for c in COURIERS:
    #     for p in PACKS:
    #         solver_unified.add(carry_num[c][p] == assignments[p][c])
    
    # Soft Constraint for symmetry breaking
    # for c1 in COURIERS:
    #     for c2 in COURIERS:
    #         if (c1 < c2 and loads[c1]==loads[c2]):
    #             for p1 in PACKS:
    #                 for p2 in PACKS:
    #                     solver_unified.add(Implies(And(carry_num[c1][p1], carry_num[c2][p2]), p1 <= p2))
                # solver_paths.add(carry_num[c1] <= carry_num[c2])

    ## Path related constraints
    # 1 - Nel path deve esistere uno step con valore del pacco True con indice = DEPOT (n+1)
    for c in COURIERS:
        # If courier has at_least_one package to deliver, its path[c][DEPOT] must have a destination != DEPOT
        solver_unified.add(Implies(at_least_one([assignments[p][c] for p in PACKS]), paths[c][DEPOT][DEPOT]==False))

        # If courier has no package to deliver, it can stay in DEPOT
        solver_unified.add(Implies(Not(at_least_one([assignments[p][c] for p in PACKS])), paths[c][DEPOT][DEPOT]==True))

        for p in PACKS:
            solver_unified.add(Implies(assignments[p][c], paths[c][p][p]==False))
            solver_unified.add(Implies(Not(assignments[p][c]), paths[c][p][p]==True))

    # 2 - ensuring pack is delivered by a single courier only once
    for c in COURIERS:
        for loc in LOCATIONS:
            solver_unified.add(exactly_one([paths[c][loc][ind] for ind in LOCATIONS]))

    ## Subcircuit constraint
    # 1 - alldifferent per ogni path di ogni courier
    for c in COURIERS:
        for loc in LOCATIONS:
            solver_unified.add(exactly_one([paths[c][ind][loc] for ind in LOCATIONS]))

    # 2 - subtour elimination
    # Variables: u[i] to prevent subtours
    u = [[[Bool(f"u_{i}_{j}_{k}") for k in PACKS] for j in PACKS] for i in COURIERS]

    # Constraining assignment of truth value of u decision variable
    for c in COURIERS:
        # u del primo pacco = 1
        for p in PACKS:
            solver_unified.add(Implies(paths[c][DEPOT][p], u[c][p][0]==True))

        # u_j >= u_i + 1
        for p1 in PACKS:
            for p2 in PACKS:
                if p1 == p2:
                    continue

                for k in PACKS:
                    solver_unified.add(Implies(And(paths[c][p1][p2], u[c][p1][k]), And(exactly_one([u[c][p2][i] for i in range(k+1, n)]))))

    ## Exatcly one true value for each u_p1
    for c in COURIERS:
        for p1 in PACKS:
            solver_unified.add(exactly_one(u[c][p1]))

    # Applying MTZ formulation constraint
    # u_i - u_j + 1 <= (n - 1) * (1 - paths[c, i, j])
    for c in COURIERS:
        for p1 in PACKS: # i
            for p2 in PACKS: #j
                if p1 == p2:
                    continue

                for k1 in PACKS:
                    for k2 in PACKS:
                        solver_unified.add(Implies(And(u[c][p1][k1], u[c][p2][k2]), k1 - k2 + 1 <= (n-1) * (1-If(paths[c][p1][p2], 1, 0))))

    # objective = max([
    #             Sum([If(paths[c][loc1][loc2], distances[loc1][loc2], 0)
    #                 for loc1 in LOCATIONS for loc2 in LOCATIONS if loc1!=loc2])
    #             for c in COURIERS
    #             ])
    
    # solver_unified.minimize(objective)
    
    return solver_unified, assignments, paths

# %% [markdown]
# ## Unified Model application

# %%
from itertools import combinations
from z3 import *
import time
import math

## Utils
def at_least_one(bool_vars):
    return Or(bool_vars)

# Sequential encoding approach
# def at_most_one(bool_vars):
#     # Introducing auxiliar variables in the same amount of the boolean variables as arg
#     aux_vars = [Bool(f'aux_{ind}') for ind in range(len(bool_vars))]

#     return And(
#         Implies(bool_vars[0], aux_vars[0]),
#         [
#             And(
#                 Implies(Or(bool_vars[i], aux_vars[i-1]), aux_vars[i]),
#                 Implies(aux_vars[i-1], Not(bool_vars[i]))
#                 )
#             for i in range(1, len(bool_vars)-1)
#         ],
#         Implies(aux_vars[len(aux_vars)-2], Not(bool_vars[len(bool_vars)-1]))
#         )

# Heule encoding approach
# Global at_most_one counter
most_counter = 0
def at_most_one(bool_vars):
    if len(bool_vars)<=4:
        return [ Not(And(pair[0], pair[1])) for pair in combinations(bool_vars, 2)]
    else:
        global most_counter
        aux_var = Bool(f'y_{most_counter}')
        
        print(bool_vars[:3] + [aux_var])
        print([Not(aux_var)] + bool_vars[3:])

        # Increment at_most_one counter
        most_counter += 1

        return And(at_most_one(bool_vars[:3] + [aux_var]) + at_most_one([Not(aux_var)] + bool_vars[3:]))

# print(at_most_one(bool_vars[:3] + [aux_var]))
# print(at_most_one([Not(aux_var)] + bool_vars[3:]))

# def at_most_one(bool_vars):
#     return [Not(And(pair[0], pair[1])) for pair in combinations(bool_vars, 2)]

def exactly_one(bool_vars):
    return at_most_one(bool_vars) + [at_least_one(bool_vars)]

def Max(vs):
  m = vs[0]
  for v in vs[1:]:
    m = If(v > m, v, m)
  return m


# Definition of Unified Model
class Unified_SeqEnc_Model():
    def __init__(self, instance):
        self.solver, self.assignment, self.paths = create_model(
            m = instance['m'],
            n = instance['n'],
            loads = instance['l'],
            sizes = instance['s'],
            distances = instance['D']
        )
        self.instance = instance
        self.distances = instance['D']


    def solve(self, timeout, random_seed):
        set_option("sat.local_search", True)
        self.solver.set("random_seed", random_seed)

        ## Useful ranges
        PACKS = range(self.instance['n'])
        COURIERS = range(self.instance['m'])
        DEPOT = (self.instance['n'])
        LOCATIONS = range(DEPOT+1)

        # Init
        objective = None
        solution_ls = []
        init_time = time.time()
        timeout_timestamp = init_time + timeout
        solve_time = timeout

        optimality = False

        while True:
            self.solver.set("timeout", math.floor(timeout_timestamp - time.time())*1000)
            status = self.solver.check()
        
            if status == unsat:
                optimality = (objective is not None)
                solve_time = math.floor(time.time() - init_time)
                break

            ## Checking timeout:
            if (time.time() >= timeout_timestamp) or status == unknown:
                break
            model = self.solver.model()

            # obtain Objective value
            objective = max([
                sum([
                    self.distances[loc1][loc2] if model.evaluate(self.paths[c][loc1][loc2]) else 0
                        for loc1 in LOCATIONS for loc2 in LOCATIONS if loc1!=loc2
                ])
            for c in COURIERS ])
        
            # Compose solution
            solution = []
            # paths_distance = []
            for c in COURIERS:
                courier_path = []

                loc1 = DEPOT
                # distance = 0
                while True:
                    step = sum([loc2+1 if model.evaluate(self.paths[c][loc1][loc2]) else 0 for loc2 in LOCATIONS if loc1!=loc2])
                    if step == 0: break # This courier does not deliver anything

                    # distance += self.distances[loc1][step-1]
                    if (step-1) == DEPOT:
                        break
                    else:
                        loc1 = step-1
                        courier_path.append(step)

                solution.append(courier_path)
                # paths_distance.append(distance)
            solution_ls.append(solution)

            # objective = max(paths_distance)
        
            # solution = [[sum([loc2+1 for loc2 in LOCATIONS if (model.evaluate(paths[c][loc1][loc2]) and loc1!=loc2)]) for loc1 in LOCATIONS] for c in COURIERS]

            # print(f'Objective: {objective}')
            # print(f'Solution: {solution}')

            for c in COURIERS:
                total_distance = Sum([If(self.paths[c][loc1][loc2], self.distances[loc1][loc2], 0) for loc1 in LOCATIONS for loc2 in LOCATIONS if loc1!=loc2])
                self.solver.add(total_distance < objective)
            
            # Constraint to ensure new assignments are different than ones already tried
            # self.solver.add(Not(And([model.evaluate(self.assignment[p][c]) == self.assignment[p][c] for c in COURIERS for p in PACKS])))

            # Provare a inserire le statistiche come output della solve
            # print ("statistics for the last check method...")
            # print (s.statistics())
            # # Traversing statistics
            # for k, v in s.statistics():
            #     print ("%s : %s" % (k, v))
        
        if (objective is not None):
            return objective, solution_ls[-1], optimality, solve_time
        else:
            return None, None, False, solve_time
    

def create_model(m, n, loads, sizes, distances):
    ## Useful ranges
    PACKS = range(n)
    COURIERS = range(m)
    DEPOT = (n)
    LOCATIONS = range(DEPOT+1)

    ###### Previous assignment model
    # Decision variables
    assignments = [[Bool(f"a_{p}_{c}") for c in COURIERS] for p in PACKS]


    solver_unified = Solver()

    # Capacity constraint - assure that sum of weights of a singular courier is under its load limit
    for c in COURIERS:
        sum_load = Sum([If(assignments[p][c], sizes[p], 0) for p in PACKS])
        solver_unified.add(sum_load <= loads[c])
    
    # Capacity constraint - ensure that each pack is delivered only by a courier
    for p in PACKS:
        solver_unified.add(exactly_one([assignments[p][c] for c in COURIERS]))
        # solver_unified.add(PbEq([(assignments[p][c], c+1) for c in COURIERS], 1))
    

    

    ###### Previous paths model
    # Decision variables
    # assignments = [[Bool(f"a_{p}_{c}") for c in COURIERS] for p in PACKS]
    paths = [[[Bool(f'p_{c}_{loc1}_{loc2}') for loc2 in LOCATIONS] for loc1 in LOCATIONS] for c in COURIERS]

    # Auxiliar variables
    # carry_num = [[Bool(f'c_{c}_{p1}') for p1 in PACKS] for c in COURIERS] # Counter of how many packages a courier is delivering

    # for c in COURIERS:
    #     for p in PACKS:
    #         solver_unified.add(carry_num[c][p] == assignments[p][c])
    
    # Soft Constraint for symmetry breaking
    # for c1 in COURIERS:
    #     for c2 in COURIERS:
    #         if (c1 < c2 and loads[c1]==loads[c2]):
    #             for p1, p2 in zip(PACKS, range):
    #                 solver_unified.add(Implies(And(carry_num[c1][p1], carry_num[c2][p2]), p1 <= p2))
                # solver_paths.add(carry_num[c1] <= carry_num[c2])

    ## Path related constraints
    # 1 - Nel path deve esistere uno step con valore del pacco True con indice = DEPOT (n+1)
    for c in COURIERS:
        # If courier has at_least_one package to deliver, its path[c][DEPOT] must have a destination != DEPOT
        solver_unified.add(Implies(at_least_one([assignments[p][c] for p in PACKS]), paths[c][DEPOT][DEPOT]==False))

        # If courier has no package to deliver, it can stay in DEPOT
        solver_unified.add(Implies(Not(at_least_one([assignments[p][c] for p in PACKS])), paths[c][DEPOT][DEPOT]==True))

        for p in PACKS:
            solver_unified.add(Implies(assignments[p][c], paths[c][p][p]==False))
            solver_unified.add(Implies(Not(assignments[p][c]), paths[c][p][p]==True))

    # 2 - ensuring pack is delivered by a single courier only once
    for c in COURIERS:
        for loc in LOCATIONS:
            solver_unified.add(exactly_one([paths[c][loc][ind] for ind in LOCATIONS]))
            # solver_unified.add(PbEq([(paths[c][loc][ind], ind+1) for ind in LOCATIONS], 1))

    ## Subcircuit constraint
    # 1 - alldifferent per ogni path di ogni courier
    for c in COURIERS:
        for loc in LOCATIONS:
            solver_unified.add(exactly_one([paths[c][ind][loc] for ind in LOCATIONS]))
            # solver_unified.add(PbEq([(paths[c][ind][loc], ind+1) for ind in LOCATIONS], 1))

    # 2 - subtour elimination
    # Variables: u[i] to prevent subtours
    u = [[[Bool(f"u_{i}_{j}_{k}") for k in PACKS] for j in PACKS] for i in COURIERS]

    # Constraining assignment of truth value of u decision variable
    for c in COURIERS:
        # u del primo pacco = 1
        for p in PACKS:
            solver_unified.add(Implies(paths[c][DEPOT][p], u[c][p][0]==True))

        # u_j >= u_i + 1
        for p1 in PACKS:
            for p2 in PACKS:
                if p1 == p2:
                    continue

                for k in PACKS:
                    solver_unified.add(Implies(And(paths[c][p1][p2], u[c][p1][k]), And(exactly_one([u[c][p2][i] for i in range(k+1, n)]))))
                    # solver_unified.add(Implies(And(paths[c][p1][p2], u[c][p1][k]), And(PbEq([(u[c][p2][i], i+1) for i in range(k+1, n)], 1))))

    ## Exatcly one true value for each u_p1
    for c in COURIERS:
        for p1 in PACKS:
            solver_unified.add(exactly_one(u[c][p1]))
            # solver_unified.add(PbEq([(u[c][p1][p2], p2+1) for p2 in PACKS], 1))

    # Applying MTZ formulation constraint
    # u_i - u_j + 1 <= (n - 1) * (1 - paths[c, i, j])
    for c in COURIERS:
        for p1 in PACKS: # i
            for p2 in PACKS: #j
                if p1 == p2:
                    continue

                for k1 in PACKS:
                    for k2 in PACKS:
                        solver_unified.add(Implies(And(u[c][p1][k1], u[c][p2][k2]), k1 - k2 + 1 <= (n-1) * (1-If(paths[c][p1][p2], 1, 0))))
    

    ##### Estimated distance for the minimum path
    lower_bound = max([distances[DEPOT][p] + distances[p][DEPOT] for p in PACKS])

    Objective = Max([
        Sum([
            If(paths[c][loc1][loc2], distances[loc1][loc2], 0)
                for loc1 in LOCATIONS for loc2 in LOCATIONS if loc1!=loc2
        ])
    for c in COURIERS ])

    # Constraint - ensuring distance percurred by each courier to be greater than estimated lower bound
    solver_unified.add(Objective >= lower_bound)
    # for c in COURIERS:
    #     total_distance = Sum([If(self.paths[c][loc1][loc2], self.distances[loc1][loc2], 0) for loc1 in LOCATIONS for loc2 in LOCATIONS if loc1!=loc2])
    #     self.solver.add(total_distance >= lower_bound)

    return solver_unified, assignments, paths

# %%
# Declaration of the Model class
problem = Unified_SeqEnc_Model(instance_collection['instance_1'])

set_option("sat.random_seed", 42)
set_option("sat.local_search", True)
# set_option("sat.restart", 'luby') # ema, luby, static or geometric
# set_option("sat.ddfw_search", True)

# Setting up pretty solution dictionary
solution_dict = {
    'objective':100000,
    'solution':None,
    'is_optimal': False,
    'time':None,
    'timeout':False,
}

# Initializing time measure
init_time = time.time()

# Setting Timeout False
# timeout = False

# Try Counter
i = 0
# while (timeout==False):
while True:

    # Obtain a first assignment to variable assignment (=> which courier deliver each pack)
    print(f'({i+1}) - try')
    objective, solution, unsat_status  = problem.solve()

    # Initializing pretty solution storage
    if objective is not None:
        if (objective < solution_dict['objective']):
            solution_dict['objective'] = objective
            solution_dict['solution'] = solution

    # Time statistics measure
    end_time = time.time()
    diff_time = end_time-init_time

    # Checking timeout
    if diff_time>=300:
        solution_dict['time'] = diff_time
        # timeout=True
        solution_dict['timeout'] = True
        break

        
    # Chacking optimality
    if unsat_status:
        solution_dict['time'] = diff_time
        solution_dict['is_optimal'] = True
        break
    i += 1
# Out:
# [p_0_0_0, p_0_0_1, p_0_0_2, y_0]
# [Not(y_0), p_0_0_3, p_0_0_4, p_0_0_5, p_0_0_6]
# [Not(y_0), p_0_0_3, p_0_0_4, y_1]
# [Not(y_1), p_0_0_5, p_0_0_6]
# ---------------------------------------------------------------------------
# Z3Exception                               Traceback (most recent call last)
# Cell In[24], line 2
#       1 # Declaration of the Model class
# ----> 2 problem = Unified_SeqEnc_Model(instance_collection['instance_1'])
#       4 set_option("sat.random_seed", 42)
#       5 set_option("sat.local_search", True)
#
# Cell In[23], line 64, in Unified_SeqEnc_Model.__init__(self, instance)
#      63 def __init__(self, instance):
# ---> 64     self.solver, self.assignment, self.paths = create_model(
#      65         m = instance['m'],
#      66         n = instance['n'],
#      67         loads = instance['l'],
#      68         sizes = instance['s'],
#      69         distances = instance['D']
#      70     )
#      71     self.instance = instance
#      72     self.distances = instance['D']
#
# Cell In[23], line 229, in create_model(m, n, loads, sizes, distances)
#     227 for c in COURIERS:
#     228     for loc in LOCATIONS:
# --> 229         solver_unified.add(exactly_one([paths[c][loc][ind] for ind in LOCATIONS]))
#     230         # solver_unified.add(PbEq([(paths[c][loc][ind], ind+1) for ind in LOCATIONS], 1))
#     231
#     232 ## Subcircuit constraint
#     233 # 1 - alldifferent per ogni path di ogni courier
#     234 for c in COURIERS:
#
# Cell In[23], line 52, in exactly_one(bool_vars)
#      51 def exactly_one(bool_vars):
# ---> 52     return at_most_one(bool_vars) + [at_least_one(bool_vars)]
#
# Cell In[23], line 43, in at_most_one(bool_vars)
#      40 # Increment at_most_one counter
#      41 most_counter += 1
# ---> 43 return And(at_most_one(bool_vars[:3] + [aux_var]) + at_most_one([Not(aux_var)] + bool_vars[3:]))
#
# File ~/miniconda3/envs/ai/lib/python3.11/site-packages/z3/z3.py:1580, in BoolRef.__radd__(self, other)
#    1579 def __radd__(self, other):
# -> 1580     return self + other
#
# File ~/miniconda3/envs/ai/lib/python3.11/site-packages/z3/z3.py:1577, in BoolRef.__add__(self, other)
#    1575 if isinstance(other, BoolRef):
#    1576     other = If(other, 1, 0)
# -> 1577 return If(self, 1, 0) + other
#
# File ~/miniconda3/envs/ai/lib/python3.11/site-packages/z3/z3.py:2478, in ArithRef.__add__(self, other)
#    2468 def __add__(self, other):
#    2469     """Create the Z3 expression `self + other`.
#    2470
#    2471     >>> x = Int('x')
#    (...)
#    2476     Int
#    2477     """
# -> 2478     a, b = _coerce_exprs(self, other)
#    2479     return ArithRef(_mk_bin(Z3_mk_add, a, b), self.ctx)
#
# File ~/miniconda3/envs/ai/lib/python3.11/site-packages/z3/z3.py:1237, in _coerce_exprs(a, b, ctx)
#    1235 s = _coerce_expr_merge(s, b)
#    1236 a = s.cast(a)
# -> 1237 b = s.cast(b)
#    1238 return (a, b)
#
# File ~/miniconda3/envs/ai/lib/python3.11/site-packages/z3/z3.py:2406, in ArithSortRef.cast(self, val)
#    2404 else:
#    2405     if self.is_int():
# -> 2406         return IntVal(val, self.ctx)
#    2407     if self.is_real():
#    2408         return RealVal(val, self.ctx)
#
# File ~/miniconda3/envs/ai/lib/python3.11/site-packages/z3/z3.py:3243, in IntVal(val, ctx)
#    3235 """Return a Z3 integer value. If `ctx=None`, then the global context is used.
#    3236
#    3237 >>> IntVal(1)
#    (...)
#    3240 100
#    3241 """
#    3242 ctx = _get_ctx(ctx)
# -> 3243 return IntNumRef(Z3_mk_numeral(ctx.ref(), _to_int_str(val), IntSort(ctx).ast), ctx)
#
# File ~/miniconda3/envs/ai/lib/python3.11/site-packages/z3/z3core.py:2361, in Z3_mk_numeral(a0, a1, a2, _elems)
#    2359 def Z3_mk_numeral(a0, a1, a2, _elems=Elementaries(_lib.Z3_mk_numeral)):
#    2360   r = _elems.f(a0, _str_to_bytes(a1), a2)
# -> 2361   _elems.Check(a0)
#    2362   return r
#
# File ~/miniconda3/envs/ai/lib/python3.11/site-packages/z3/z3core.py:1554, in Elementaries.Check(self, ctx)
#    1552 err = self.get_error_code(ctx)
#    1553 if err != self.OK:
# -> 1554     raise self.Exception(self.get_error_message(ctx, err))
#
# Z3Exception: b'parser error'

# %%
solution_dict
# Out:
# {'objective': 100000,
#  'solution': None,
#  'is_optimal': True,
#  'time': 10.853698253631592,
#  'timeout': False}
